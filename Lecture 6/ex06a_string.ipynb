# %% [markdown]
# ### Creating Strings

# %% [markdown]
# #### 1 - Basic Creation
# Create strings using single quotes, double quotes, and triple single and double quotes. Print them to confirm theyâ€™re the same.

# %%
string = 'Hello'
string_a = "Hello"
string_b = """Hello"""
string_d = '''Hello'''
print(string)
print(string_a)
print(string_b)
print(string == string_a)
print(string_a == string_b)
print(string_b == string_d)
# Out:
# Hello
# Hello
# Hello
# True
# True
# True

# %% [markdown]
# #### 2 - Quotes Inside Strings
# Write a string that contains both single and double quotes without using escape characters.

# %%
string = ''''Hello' "world"'''
print(string)
# Out:
# 'Hello' "world"

# %% [markdown]
# #### 3 - Multiline String
# Create a string that spans multiple lines using triple quotes and print it.

# %%
spring = '''Hello
what
are
you'''
print(spring)
# Out:
# Hello
# what
# are
# you

# %% [markdown]
# ### Escape Sequences

# %% [markdown]
# #### 4 - Common Escapes
#
# Print the following using escape sequences:
#
# A sentence with an apostrophe (`It's fine`)
#
# A path `C:\Users\Python\Scripts`
#
# Two words separated by a tab
#
# Two words separated by a newline

# %%
print("it\' fine")
print('C:\\Users\\Python\\Scripts')
print('new\tline')
print('new\nLine')
# Out:
# it' fine
# C:\Users\Python\Scripts
# new	line
# new
# Line

# %% [markdown]
# #### 5 - Unicode Characters
#
# Print:
#
# The Greek letter Omega using \u
#
# The ðŸ˜€ emoji using \U
#
# A character using its octal and hex escape codes

# %%
print('\u03A9')
print('\U0001F600')
print('\101')
# Out:
# Ω
# 😀
# A

# %% [markdown]
# ### String Constructors

# %% [markdown]
# #### 6 - Convert to String
#
# Use str() to convert and print the following:
#
# An integer, float, bool, tuple, list, set and dict

# %%
print(str(9))
print(str(9.0))
print(str(True))
print(str([1,2,3]))
print(str({1:'d',2:'t'}))
# Out:
# 9
# 9.0
# True
# [1, 2, 3]
# {1: 'd', 2: 't'}

# %% [markdown]
# #### 7 - Function Conversion
#
# Write a function convert_to_str(val) that prints both the original type and its string form. Test it with a number, range, tuple, list, set and dictionary.

# %%
def convert_to_str(x):
    new_string = str(x)
    print(type(x))
    print(new_string)

convert_to_str(1)
convert_to_str(2.0)
convert_to_str([1,2])
convert_to_str({3:2,4:2})
# Out:
# <class 'int'>
# 1
# <class 'float'>
# 2.0
# <class 'list'>
# [1, 2]
# <class 'dict'>
# {3: 2, 4: 2}

# %% [markdown]
# ### String Methods

# %% [markdown]
# #### 8 - Trimming and Case
# Given a = ' python programming ', use string methods to:
#
# Remove leading spaces
#
# Remove trailing spaces
#
# Convert to uppercase
#
# Convert to title case

# %%
a = ' python programming'
print(f'{a.lstrip()}')
print(f'{a.rstrip()}')
print(f'{a.upper()}')
print(f'{a.title()}')
# Out:
# python programming
#  python programming
#  PYTHON PROGRAMMING
#  Python Programming

# %% [markdown]
# #### 9 - Find and Replace
# Write a program that:
#
# Finds the first occurrence of 'p' in 'python'.
#
# Replaces 'o' with '0'.

# %% [markdown]
# #### 10 - Splitting
# Split the string 'apple,banana,cherry' into a list.

# %% [markdown]
# ### Boolean Methods
#
# #### 11 - Character Checks
# Write a loop that checks if each character in ['A', 'z', '5', ' '] is:
#
# A digit
#
# Alphabetic
#
# Uppercase
#
# Lowercase
#
# Whitespace

# %% [markdown]
# ### Formatting Strings

# %% [markdown]
# #### 12 - Right-Aligned Numbers
# Print a table that aligns numbers like this (using f-strings):
#
#   1
#  10
# 100
# 999

# %% [markdown]
# #### 13 - Currency Formatting
# Convert 1234567.89 into:
#
# Comma separated format â†’ 1,234,567.89
#
# Underscore separated format â†’ 1_234_567.89

# %% [markdown]
# #### 14 - Percentage Formatting
# Convert 0.075 into 7.5%.

# %% [markdown]
# ### Raw Strings
#
# #### 15 - File Path Raw String
# Print the Windows path C:\Program Files\Python as a raw string, so that backslashes are not interpreted as escapes.
